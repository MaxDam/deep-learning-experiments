# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.externals import joblib 
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers import BatchNormalization, Concatenate,concatenate
from keras.models import load_model
from keras.optimizers import Adam
from keras.layers import Input
from keras.models import Model
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
import seaborn as sn
from keras.utils import to_categorical
from sklearn.datasets.samples_generator import make_blobs

# %% [markdown]
# ## Iperparametri

# %%
learning_rate = 0.001
dropout_rate = 0.5

hidden_layers = [600, 100] #soluzione1
#hidden_layers = [5000, 3000, 1000] #soluzione2
n_output = 7

batch_size = 250
epochs = 150

#loss='categorical_crossentropy'
loss='binary_crossentropy'

# %% [markdown]
# ## Crea i dati di input

# %%
def balanceCategoricalData(df):
    all = df.iloc[:, :].values.astype(np.float32)
    A = all[all[:,-1]<70]
    B = all[(all[:,-1]>=70)&(all[:,-1]<=83)]
    C = all[(all[:,-1]>=84)&(all[:,-1]<=98)] 
    D = all[(all[:,-1]>=99)&(all[:,-1]<=113)] 
    E = all[(all[:,-1]>=114)&(all[:,-1]<=128)] 
    F = all[(all[:,-1]>=129)&(all[:,-1]<=143)] 
    G = all[all[:,-1]>143]

    #prende solo una parte dei dati della categoria A
    A = A[0:330,:]

    #crea nuovamente il dataframe dopo aver pre-elaborato i dati
    data = np.concatenate((A,B,C,D,E,F,G), axis=0)
    np.random.shuffle(data)
    df = pd.DataFrame(data=data)
    return df

def getClassGeneratedInputData(std=1, graph=[0,1]):
    #crea 1000 campioni di 48 input divisi in 7 classi separate
    X, y = make_blobs(n_samples=1000, n_features=48, centers=7, cluster_std=std)

    #stampa i dati
    df = pd.DataFrame(dict(x=X[:,graph[0]], y=X[:,graph[1]], label=y))
    colors = {0:'red', 1:'blue', 2:'green', 3:'black', 4:'gray', 5:'orange', 6:'yellow', 7:'purple'}
    fig, ax = plt.subplots()
    grouped = df.groupby('label')
    for key, group in grouped:
        group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
    plt.title('data generated')
    plt.show()
    
    #prepara i dati di input e output
    minMaxScaler = preprocessing.MinMaxScaler()
    X = minMaxScaler.fit_transform(X)
    X1 = X[:, 0:24]
    X2 = X[:, 24:48]
    y = to_categorical(y)

    #separa i dati di training dai dati di test
    test_size=0.33
    return train_test_split(X1, X2, y, test_size=test_size, random_state=42)

def transformToClass(yr):
    yc = []
    for i in range(len(yr)):
        yi = np.zeros(7)
        if (yr[i]<70):                  yi[0] = 1 #A
        if (yr[i]>=70  and yr[i]<=83) : yi[1] = 1 #B
        if (yr[i]>=84  and yr[i]<=98) : yi[2] = 1 #C
        if (yr[i]>=99  and yr[i]<=113): yi[3] = 1 #D
        if (yr[i]>=114 and yr[i]<=128): yi[4] = 1 #E
        if (yr[i]>=129 and yr[i]<=143): yi[5] = 1 #F
        if (yr[i]>143):                 yi[6] = 1 #G
        yc.append(yi)
    yr = np.array(yc)
    return yr

#funzione che conta gli elementi per ogni classe
def printCountClass(yr):
    print("A: ",len(yr[yr<70]))
    print("B: ",len(yr[(yr>=70)&(yr<=83)]))
    print("C: ",len(yr[(yr>=84)&(yr<=98)]))
    print("D: ",len(yr[(yr>=99)&(yr<=113)]))
    print("E: ",len(yr[(yr>=114)&(yr<=128)]))
    print("F: ",len(yr[(yr>=129)&(yr<=143)]))
    print("G: ",len(yr[yr>143]))
    
def getClassSingleInputData(df, graph=[0,1]):
    #ottiene gli input
    n_input = 24
    X1 = df.iloc[:, :n_input].values.astype(np.float32)
    X2 = df.iloc[:, n_input:n_input*2].values.astype(np.float32)
    #X = ((X1-1)*5+X2)/(5*5)
    #X = np.abs(X1-X2)/5 #soluzione1
    #X = np.concatenate([X1,X2], axis=1)/5 # soluzione2
    X = np.concatenate([X1,X2,X1+X2,X1*X2], axis=1)/5
    
    #ottiene gli output e li trasforma in classi    
    y = df.iloc[:, -1].values.astype(np.float32)
    y = transformToClass(y)

    #stampa i dati
    _X = X
    _y = np.argmax(y, axis=1)
    df = pd.DataFrame(dict(x=_X[:,graph[0]], y=_X[:,graph[1]], label=_y))
    colors = {0:'red', 1:'blue', 2:'green', 3:'black', 4:'gray', 5:'orange', 6:'yellow', 7:'purple'}
    fig, ax = plt.subplots()
    grouped = df.groupby('label')
    for key, group in grouped:
        group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
    plt.title('input data')
    plt.show()
    
    #separa dati di train da dati di test
    test_size=0.33
    return train_test_split(X, y, test_size=test_size, random_state=42)

def getRegSingleInputData(df, graph=[0,1]):
    #ottiene gli input
    n_input = 24
    X1 = df.iloc[:, :n_input].values.astype(np.float32)
    X2 = df.iloc[:, n_input:n_input*2].values.astype(np.float32)
    #X = ((X1-1)*5+X2)/(5*5)
    X = np.abs(X1-X2)/5
    
    #ottiene gli output e li trasforma in classi    
    y = df.iloc[:, -1].values.astype(np.float32)
    y = y / 200
    
    #separa dati di train da dati di test
    test_size=0.33
    return train_test_split(X, y, test_size=test_size, random_state=42)

# %%
df = pd.read_csv('patterns10000.csv')
#from google.colab import drive
#drive.mount('/content/drive')
#df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/patterns.csv')
df = balanceCategoricalData(df)

#X1_train, X1_test, X2_train, X2_test, y_train, y_test = getClassGeneratedInputData(std=12)

X_train, X_test, y_train, y_test = getClassSingleInputData(df)
#X_train, X_test, y_train, y_test = getRegSingleInputData(df)
X_train.shape
# Out:
# (4067, 96)

# %% [markdown]
# ## Crea ed addestra il modello

# %%
def autoencoder():
    #hidden_dim = 36
    encoding_dim = 24
    n_input = X_train.shape[1]
    inputLayer = Input(shape=(n_input, ))
    
    encoderLayer = inputLayer
    encoderLayer = Dense(40, activation="sigmoid")(encoderLayer)
    encoderLayer = Dense(30, activation="sigmoid")(encoderLayer)
    #encoderLayer = Dropout(dropout_rate)(encoderLayer)
    
    middleLayer = Dense(encoding_dim, activation="relu")(encoderLayer)
    
    decoderLayer = middleLayer
    decoderLayer = Dense(30, activation='sigmoid')(decoderLayer)
    decoderLayer = Dense(40, activation='sigmoid')(decoderLayer)
    #decoderLayer = Dropout(dropout_rate)(decoderLayer)
    
    outputLayer = Dense(n_input, activation='sigmoid')(decoderLayer)
    
    model = Model(inputs=inputLayer, outputs=outputLayer)
    encoder = Model(inputs=inputLayer, outputs=middleLayer)

    #compila l'autoencoder
    optimizer = Adam(lr=learning_rate)
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['accuracy'])

    #addestra l'autoencoder
    history = model.fit(X_train, X_train, epochs=epochs, batch_size=batch_size, shuffle=True, validation_split=0.3, verbose=1)

    return model, encoder, history

def modelClassificationMonoInput():
    n_input = X_train.shape[1]
    
    input = Input((n_input,))

    layer = input
    for i in range(len(hidden_layers)):
        #aggiunge lo strato nascosto
        #layer = BatchNormalization()(layer)
        layer = Dense(hidden_layers[i])(layer)
        layer = Dropout(dropout_rate)(layer)
        layer = Activation('relu')(layer)

    #aggiunge lo strato di uscita
    #layer = BatchNormalization()(layer)
    layer = Dense(n_output)(layer)
    layer = Dropout(dropout_rate)(layer)
    output = Activation('softmax')(layer)

    #crea il modello
    model = Model(input, output)

    #compila la rete neurale
    optimizer = Adam(lr=learning_rate)
    model.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

    #addestra la rete neurale
    history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_test, y_test), verbose=1) 
    
    return model, history

def modelRegressionMonoInput():
    n_input = X_train.shape[1]
    input = Input((n_input,))

    layer = input
    for i in range(len(hidden_layers)):
        #aggiunge lo strato nascosto
        layer = Dense(hidden_layers[i])(layer)
        layer = Dropout(dropout_rate)(layer)
        layer = Activation('relu')(layer)

    #aggiunge lo strato di uscita
    output = Dense(1)(layer)

    #crea il modello
    model = Model(input, output)

    #compila la rete neurale
    optimizer = Adam(lr=learning_rate)
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mae'])

    #addestra la rete neurale
    history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_test, y_test), verbose=1)
    
    return model, history

# %%
#autoencoder
#model, encoder, history = autoencoder()
#print(model.evaluate(X_test, X_test, verbose=0))
#X_train = encoder.predict(X_train)
#X_test = encoder.predict(X_test)

model, history = modelClassificationMonoInput()
#model, history = modelRegressionMonoInput()
# Out:
# Train on 4067 samples, validate on 2004 samples
# Epoch 1/150
# 4067/4067 [==============================] - 1s 181us/step - loss: 0.4403 - acc: 0.8451 - val_loss: 0.3838 - val_acc: 0.8571
# Epoch 2/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.3909 - acc: 0.8541 - val_loss: 0.3760 - val_acc: 0.8571
# Epoch 3/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.3862 - acc: 0.8555 - val_loss: 0.3674 - val_acc: 0.8571
# Epoch 4/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3876 - acc: 0.8555 - val_loss: 0.3702 - val_acc: 0.8571
# Epoch 5/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.3835 - acc: 0.8557 - val_loss: 0.3644 - val_acc: 0.8571
# Epoch 6/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3801 - acc: 0.8555 - val_loss: 0.3616 - val_acc: 0.8571
# Epoch 7/150
# 4067/4067 [==============================] - 0s 51us/step - loss: 0.3826 - acc: 0.8565 - val_loss: 0.3651 - val_acc: 0.8571
# Epoch 8/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3805 - acc: 0.8559 - val_loss: 0.3613 - val_acc: 0.8571
# Epoch 9/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3790 - acc: 0.8568 - val_loss: 0.3615 - val_acc: 0.8571
# Epoch 10/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.3782 - acc: 0.8569 - val_loss: 0.3577 - val_acc: 0.8571
# Epoch 11/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3787 - acc: 0.8565 - val_loss: 0.3595 - val_acc: 0.8571
# Epoch 12/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.3769 - acc: 0.8565 - val_loss: 0.3597 - val_acc: 0.8571
# Epoch 13/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3764 - acc: 0.8563 - val_loss: 0.3531 - val_acc: 0.8571
# Epoch 14/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3783 - acc: 0.8567 - val_loss: 0.3569 - val_acc: 0.8571
# Epoch 15/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.3748 - acc: 0.8553 - val_loss: 0.3529 - val_acc: 0.8571
# Epoch 16/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.3731 - acc: 0.8563 - val_loss: 0.3517 - val_acc: 0.8571
# Epoch 17/150
# 4067/4067 [==============================] - 0s 60us/step - loss: 0.3735 - acc: 0.8570 - val_loss: 0.3508 - val_acc: 0.8571
# Epoch 18/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3749 - acc: 0.8563 - val_loss: 0.3501 - val_acc: 0.8571
# Epoch 19/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.3721 - acc: 0.8561 - val_loss: 0.3506 - val_acc: 0.8571
# Epoch 20/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3726 - acc: 0.8563 - val_loss: 0.3509 - val_acc: 0.8571
# Epoch 21/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3720 - acc: 0.8566 - val_loss: 0.3475 - val_acc: 0.8571
# Epoch 22/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3715 - acc: 0.8562 - val_loss: 0.3454 - val_acc: 0.8571
# Epoch 23/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3682 - acc: 0.8572 - val_loss: 0.3435 - val_acc: 0.8571
# Epoch 24/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3715 - acc: 0.8565 - val_loss: 0.3469 - val_acc: 0.8571
# Epoch 25/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3690 - acc: 0.8561 - val_loss: 0.3438 - val_acc: 0.8571
# Epoch 26/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.3670 - acc: 0.8571 - val_loss: 0.3391 - val_acc: 0.8571
# Epoch 27/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.3666 - acc: 0.8573 - val_loss: 0.3427 - val_acc: 0.8571
# Epoch 28/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3686 - acc: 0.8573 - val_loss: 0.3431 - val_acc: 0.8571
# Epoch 29/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.3650 - acc: 0.8582 - val_loss: 0.3380 - val_acc: 0.8571
# Epoch 30/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.3671 - acc: 0.8569 - val_loss: 0.3409 - val_acc: 0.8571
# Epoch 31/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3678 - acc: 0.8565 - val_loss: 0.3418 - val_acc: 0.8571
# Epoch 32/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.3647 - acc: 0.8573 - val_loss: 0.3386 - val_acc: 0.8571
# Epoch 33/150
# 4067/4067 [==============================] - 0s 62us/step - loss: 0.3660 - acc: 0.8569 - val_loss: 0.3368 - val_acc: 0.8571
# Epoch 34/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3634 - acc: 0.8572 - val_loss: 0.3368 - val_acc: 0.8571
# Epoch 35/150
# 4067/4067 [==============================] - 0s 63us/step - loss: 0.3613 - acc: 0.8572 - val_loss: 0.3385 - val_acc: 0.8571
# Epoch 36/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3618 - acc: 0.8578 - val_loss: 0.3336 - val_acc: 0.8571
# Epoch 37/150
# 4067/4067 [==============================] - 0s 52us/step - loss: 0.3633 - acc: 0.8575 - val_loss: 0.3383 - val_acc: 0.8571
# Epoch 38/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.3625 - acc: 0.8571 - val_loss: 0.3345 - val_acc: 0.8572
# Epoch 39/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.3613 - acc: 0.8580 - val_loss: 0.3309 - val_acc: 0.8571
# Epoch 40/150
# 4067/4067 [==============================] - 0s 61us/step - loss: 0.3597 - acc: 0.8579 - val_loss: 0.3322 - val_acc: 0.8571
# Epoch 41/150
# 4067/4067 [==============================] - 0s 62us/step - loss: 0.3618 - acc: 0.8561 - val_loss: 0.3309 - val_acc: 0.8571
# Epoch 42/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.3611 - acc: 0.8562 - val_loss: 0.3275 - val_acc: 0.8573
# Epoch 43/150
# 4067/4067 [==============================] - 0s 65us/step - loss: 0.3573 - acc: 0.8585 - val_loss: 0.3259 - val_acc: 0.8572
# Epoch 44/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3573 - acc: 0.8586 - val_loss: 0.3283 - val_acc: 0.8573
# Epoch 45/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.3541 - acc: 0.8589 - val_loss: 0.3228 - val_acc: 0.8572
# Epoch 46/150
# 4067/4067 [==============================] - 0s 59us/step - loss: 0.3577 - acc: 0.8568 - val_loss: 0.3226 - val_acc: 0.8571
# Epoch 47/150
# 4067/4067 [==============================] - 0s 59us/step - loss: 0.3550 - acc: 0.8576 - val_loss: 0.3236 - val_acc: 0.8572
# Epoch 48/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3552 - acc: 0.8573 - val_loss: 0.3219 - val_acc: 0.8572
# Epoch 49/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3539 - acc: 0.8583 - val_loss: 0.3191 - val_acc: 0.8571
# Epoch 50/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3500 - acc: 0.8580 - val_loss: 0.3174 - val_acc: 0.8571
# Epoch 51/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.3494 - acc: 0.8593 - val_loss: 0.3156 - val_acc: 0.8571
# Epoch 52/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3505 - acc: 0.8598 - val_loss: 0.3153 - val_acc: 0.8572
# Epoch 53/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3505 - acc: 0.8590 - val_loss: 0.3119 - val_acc: 0.8570
# Epoch 54/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.3498 - acc: 0.8593 - val_loss: 0.3109 - val_acc: 0.8570
# Epoch 55/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.3473 - acc: 0.8589 - val_loss: 0.3080 - val_acc: 0.8571
# Epoch 56/150
# 4067/4067 [==============================] - 0s 59us/step - loss: 0.3477 - acc: 0.8578 - val_loss: 0.3110 - val_acc: 0.8574
# Epoch 57/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.3433 - acc: 0.8613 - val_loss: 0.3049 - val_acc: 0.8571
# Epoch 58/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.3429 - acc: 0.8595 - val_loss: 0.3115 - val_acc: 0.8572
# Epoch 59/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.3443 - acc: 0.8597 - val_loss: 0.3028 - val_acc: 0.8569
# Epoch 60/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.3431 - acc: 0.8595 - val_loss: 0.3024 - val_acc: 0.8571
# Epoch 61/150
# 4067/4067 [==============================] - 0s 60us/step - loss: 0.3440 - acc: 0.8593 - val_loss: 0.3003 - val_acc: 0.8571
# Epoch 62/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3423 - acc: 0.8601 - val_loss: 0.2982 - val_acc: 0.8570
# Epoch 63/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.3413 - acc: 0.8602 - val_loss: 0.2977 - val_acc: 0.8568
# Epoch 64/150
# 4067/4067 [==============================] - 0s 60us/step - loss: 0.3379 - acc: 0.8604 - val_loss: 0.2976 - val_acc: 0.8572
# Epoch 65/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.3367 - acc: 0.8622 - val_loss: 0.2910 - val_acc: 0.8570
# Epoch 66/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3345 - acc: 0.8621 - val_loss: 0.2916 - val_acc: 0.8578
# Epoch 67/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3344 - acc: 0.8608 - val_loss: 0.2869 - val_acc: 0.8584
# Epoch 68/150
# 4067/4067 [==============================] - 0s 60us/step - loss: 0.3353 - acc: 0.8620 - val_loss: 0.2886 - val_acc: 0.8576
# Epoch 69/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.3324 - acc: 0.8628 - val_loss: 0.2890 - val_acc: 0.8576
# Epoch 70/150
# 4067/4067 [==============================] - 0s 60us/step - loss: 0.3313 - acc: 0.8629 - val_loss: 0.2873 - val_acc: 0.8569
# Epoch 71/150
# 4067/4067 [==============================] - 0s 60us/step - loss: 0.3290 - acc: 0.8635 - val_loss: 0.2823 - val_acc: 0.8628
# Epoch 72/150
# 4067/4067 [==============================] - 0s 61us/step - loss: 0.3295 - acc: 0.8643 - val_loss: 0.2797 - val_acc: 0.8601
# Epoch 73/150
# 4067/4067 [==============================] - 0s 59us/step - loss: 0.3289 - acc: 0.8647 - val_loss: 0.2798 - val_acc: 0.8592
# Epoch 74/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.3267 - acc: 0.8647 - val_loss: 0.2759 - val_acc: 0.8599
# Epoch 75/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3287 - acc: 0.8626 - val_loss: 0.2842 - val_acc: 0.8579
# Epoch 76/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.3292 - acc: 0.8643 - val_loss: 0.2777 - val_acc: 0.8581
# Epoch 77/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.3247 - acc: 0.8655 - val_loss: 0.2713 - val_acc: 0.8628
# Epoch 78/150
# 4067/4067 [==============================] - 0s 62us/step - loss: 0.3219 - acc: 0.8661 - val_loss: 0.2701 - val_acc: 0.8619
# Epoch 79/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.3199 - acc: 0.8679 - val_loss: 0.2681 - val_acc: 0.8619
# Epoch 80/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.3211 - acc: 0.8673 - val_loss: 0.2644 - val_acc: 0.8677
# Epoch 81/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.3198 - acc: 0.8680 - val_loss: 0.2632 - val_acc: 0.8653
# Epoch 82/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.3183 - acc: 0.8663 - val_loss: 0.2632 - val_acc: 0.8673
# Epoch 83/150
# 4067/4067 [==============================] - 0s 60us/step - loss: 0.3150 - acc: 0.8710 - val_loss: 0.2579 - val_acc: 0.8711
# Epoch 84/150
# 4067/4067 [==============================] - 0s 61us/step - loss: 0.3149 - acc: 0.8704 - val_loss: 0.2572 - val_acc: 0.8746
# Epoch 85/150
# 4067/4067 [==============================] - 0s 60us/step - loss: 0.3176 - acc: 0.8705 - val_loss: 0.2594 - val_acc: 0.8681
# Epoch 86/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.3155 - acc: 0.8687 - val_loss: 0.2576 - val_acc: 0.8676
# Epoch 87/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.3141 - acc: 0.8709 - val_loss: 0.2571 - val_acc: 0.8692
# Epoch 88/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3122 - acc: 0.8719 - val_loss: 0.2475 - val_acc: 0.8793
# Epoch 89/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.3101 - acc: 0.8715 - val_loss: 0.2608 - val_acc: 0.8641
# Epoch 90/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.3134 - acc: 0.8715 - val_loss: 0.2571 - val_acc: 0.8676
# Epoch 91/150
# 4067/4067 [==============================] - 0s 59us/step - loss: 0.3103 - acc: 0.8739 - val_loss: 0.2475 - val_acc: 0.8761
# Epoch 92/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.3072 - acc: 0.8745 - val_loss: 0.2467 - val_acc: 0.8773
# Epoch 93/150
# 4067/4067 [==============================] - 0s 62us/step - loss: 0.3089 - acc: 0.8741 - val_loss: 0.2471 - val_acc: 0.8760
# Epoch 94/150
# 4067/4067 [==============================] - 0s 60us/step - loss: 0.3097 - acc: 0.8745 - val_loss: 0.2518 - val_acc: 0.8692
# Epoch 95/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.3072 - acc: 0.8759 - val_loss: 0.2400 - val_acc: 0.8842
# Epoch 96/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.3054 - acc: 0.8738 - val_loss: 0.2452 - val_acc: 0.8739
# Epoch 97/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.3055 - acc: 0.8758 - val_loss: 0.2385 - val_acc: 0.8836
# Epoch 98/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.3041 - acc: 0.8767 - val_loss: 0.2382 - val_acc: 0.8812
# Epoch 99/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.2995 - acc: 0.8777 - val_loss: 0.2448 - val_acc: 0.8750
# Epoch 100/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.3032 - acc: 0.8767 - val_loss: 0.2407 - val_acc: 0.8813
# Epoch 101/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.3002 - acc: 0.8794 - val_loss: 0.2363 - val_acc: 0.8841
# Epoch 102/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.2964 - acc: 0.8791 - val_loss: 0.2301 - val_acc: 0.8904
# Epoch 103/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.2980 - acc: 0.8776 - val_loss: 0.2288 - val_acc: 0.8940
# Epoch 104/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.2977 - acc: 0.8784 - val_loss: 0.2310 - val_acc: 0.8878
# Epoch 105/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.2912 - acc: 0.8830 - val_loss: 0.2268 - val_acc: 0.8928
# Epoch 106/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.2914 - acc: 0.8827 - val_loss: 0.2274 - val_acc: 0.8924
# Epoch 107/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.2932 - acc: 0.8811 - val_loss: 0.2283 - val_acc: 0.8931
# Epoch 108/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.2989 - acc: 0.8776 - val_loss: 0.2280 - val_acc: 0.8917
# Epoch 109/150
# 4067/4067 [==============================] - 0s 72us/step - loss: 0.2943 - acc: 0.8807 - val_loss: 0.2221 - val_acc: 0.8983
# Epoch 110/150
# 4067/4067 [==============================] - 0s 70us/step - loss: 0.2958 - acc: 0.8817 - val_loss: 0.2269 - val_acc: 0.8928
# Epoch 111/150
# 4067/4067 [==============================] - 0s 59us/step - loss: 0.2922 - acc: 0.8825 - val_loss: 0.2202 - val_acc: 0.8986
# Epoch 112/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.2966 - acc: 0.8799 - val_loss: 0.2294 - val_acc: 0.8935
# Epoch 113/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.2880 - acc: 0.8846 - val_loss: 0.2208 - val_acc: 0.8983
# Epoch 114/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.2889 - acc: 0.8831 - val_loss: 0.2171 - val_acc: 0.9026
# Epoch 115/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.2848 - acc: 0.8865 - val_loss: 0.2200 - val_acc: 0.9004
# Epoch 116/150
# 4067/4067 [==============================] - 0s 52us/step - loss: 0.2834 - acc: 0.8857 - val_loss: 0.2149 - val_acc: 0.9080
# Epoch 117/150
# 4067/4067 [==============================] - 0s 61us/step - loss: 0.2848 - acc: 0.8850 - val_loss: 0.2225 - val_acc: 0.8985
# Epoch 118/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.2871 - acc: 0.8866 - val_loss: 0.2111 - val_acc: 0.9091
# Epoch 119/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.2816 - acc: 0.8864 - val_loss: 0.2138 - val_acc: 0.9068
# Epoch 120/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.2796 - acc: 0.8876 - val_loss: 0.2081 - val_acc: 0.9127
# Epoch 121/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.2810 - acc: 0.8871 - val_loss: 0.2077 - val_acc: 0.9111
# Epoch 122/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.2845 - acc: 0.8854 - val_loss: 0.2086 - val_acc: 0.9117
# Epoch 123/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.2804 - acc: 0.8878 - val_loss: 0.2069 - val_acc: 0.9137
# Epoch 124/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.2760 - acc: 0.8905 - val_loss: 0.2048 - val_acc: 0.9154
# Epoch 125/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.2825 - acc: 0.8872 - val_loss: 0.2084 - val_acc: 0.9117
# Epoch 126/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.2770 - acc: 0.8891 - val_loss: 0.2014 - val_acc: 0.9161
# Epoch 127/150
# 4067/4067 [==============================] - 0s 59us/step - loss: 0.2734 - acc: 0.8903 - val_loss: 0.2024 - val_acc: 0.9153
# Epoch 128/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.2756 - acc: 0.8894 - val_loss: 0.2019 - val_acc: 0.9142
# Epoch 129/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.2780 - acc: 0.8889 - val_loss: 0.2123 - val_acc: 0.9075
# Epoch 130/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.2782 - acc: 0.8879 - val_loss: 0.1994 - val_acc: 0.9170
# Epoch 131/150
# 4067/4067 [==============================] - 0s 52us/step - loss: 0.2762 - acc: 0.8901 - val_loss: 0.2038 - val_acc: 0.9108
# Epoch 132/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.2804 - acc: 0.8892 - val_loss: 0.1995 - val_acc: 0.9158
# Epoch 133/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.2719 - acc: 0.8930 - val_loss: 0.2121 - val_acc: 0.9062
# Epoch 134/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.2752 - acc: 0.8885 - val_loss: 0.2077 - val_acc: 0.9088
# Epoch 135/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.2696 - acc: 0.8923 - val_loss: 0.2002 - val_acc: 0.9152
# Epoch 136/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.2731 - acc: 0.8916 - val_loss: 0.1998 - val_acc: 0.9160
# Epoch 137/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.2740 - acc: 0.8910 - val_loss: 0.2156 - val_acc: 0.9028
# Epoch 138/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.2751 - acc: 0.8900 - val_loss: 0.2074 - val_acc: 0.9090
# Epoch 139/150
# 4067/4067 [==============================] - 0s 58us/step - loss: 0.2751 - acc: 0.8896 - val_loss: 0.2106 - val_acc: 0.9073
# Epoch 140/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.2784 - acc: 0.8875 - val_loss: 0.1964 - val_acc: 0.9170
# Epoch 141/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.2738 - acc: 0.8905 - val_loss: 0.1982 - val_acc: 0.9132
# Epoch 142/150
# 4067/4067 [==============================] - 0s 52us/step - loss: 0.2717 - acc: 0.8906 - val_loss: 0.1979 - val_acc: 0.9155
# Epoch 143/150
# 4067/4067 [==============================] - 0s 53us/step - loss: 0.2803 - acc: 0.8882 - val_loss: 0.1968 - val_acc: 0.9198
# Epoch 144/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.2686 - acc: 0.8929 - val_loss: 0.1917 - val_acc: 0.9231
# Epoch 145/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.2649 - acc: 0.8944 - val_loss: 0.1997 - val_acc: 0.9157
# Epoch 146/150
# 4067/4067 [==============================] - 0s 54us/step - loss: 0.2658 - acc: 0.8927 - val_loss: 0.1924 - val_acc: 0.9206
# Epoch 147/150
# 4067/4067 [==============================] - 0s 59us/step - loss: 0.2635 - acc: 0.8959 - val_loss: 0.1893 - val_acc: 0.9221
# Epoch 148/150
# 4067/4067 [==============================] - 0s 56us/step - loss: 0.2670 - acc: 0.8922 - val_loss: 0.1885 - val_acc: 0.9211
# Epoch 149/150
# 4067/4067 [==============================] - 0s 55us/step - loss: 0.2629 - acc: 0.8959 - val_loss: 0.1904 - val_acc: 0.9199
# Epoch 150/150
# 4067/4067 [==============================] - 0s 57us/step - loss: 0.2639 - acc: 0.8945 - val_loss: 0.1882 - val_acc: 0.9222

# %% [markdown]
# ## Stampa le perdite

# %%
def plotClassHistory():
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    
    # summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    
def plotRegHistory():
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

    # summarize history for accuracy
    plt.plot(history.history['mean_absolute_error'])
    plt.plot(history.history['val_mean_absolute_error'])
    plt.title('model MAE')
    plt.ylabel('MAE')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

# %%
plotClassHistory()
#plotRegHistory()

# %% [markdown]
# ## Valuta il modello

# %%
def getRegLabelAndPredictionsSingleInput():
    _predictions = model.predict(X_test).flatten()*200
    _labels = y_test*200
    return _labels, _predictions

def getClassLabelAndPredictionsSingleInput():
    #ottiene le predictions dal modello
    res_prediction = model.predict(X_test)
    _labels = y_test

    _predictions = np.zeros_like(res_prediction)
    for i in range(len(res_prediction)):
        _predictions[i, np.argmax(res_prediction[i])] = 1
    
    return _labels, _predictions

def getClassLabelAndPredictionsDoubleInput():
    #ottiene le predictions dal modello
    res_prediction = model.predict([X1_test, X2_test])
    _labels = y_test

    _predictions = np.zeros_like(res_prediction)
    for i in range(len(res_prediction)):
        _predictions[i, np.argmax(res_prediction[i])] = 1
    
    return _labels, _predictions

def printSingleInputScore():
    score = model.evaluate(X_test, y_test, verbose=0)
    print('test score:', score[0])
    print('test accuracy:', score[1])

def printDoubleInputScore():
    score = model.evaluate([X1_test, X2_test], y_test, verbose=0)
    print('test score:', score[0])
    print('test accuracy:', score[1])
    
def printR2Score(_predictions, _labels):
    
    #ottiene l' R^2 score (ottimo valore se tendente a 1)
    r_square = r2_score(_labels, _predictions) 

    #ottiene il Mean Absolute Error (MAE) (ottimo valore se tendente a 0)
    mae = mean_absolute_error(_labels, _predictions)

    #ottiene il Root Mean Squared Error (RMSE) (ottimo valore se tendente a 0)
    rmse = mean_squared_error(_labels, _predictions)**0.5

    #stampa le varie discrepanze (differenza tra il valore atteso ed il valore predetto)
    discrepancies = []
    for i in range(len(labels)):
        discrepancies.append(_labels[i]-_predictions[i])
    plt.title('Evaluating regression model')
    plt.plot(discrepancies, label='Discrepancies', color='orange')
    plt.axhline(y=mae, color='b', linestyle='--', label='MAE')
    plt.axhline(y=-mae, color='b', linestyle='--')
    plt.axhline(y=rmse, color='r', linestyle='--', label='RMSE')
    plt.axhline(y=-rmse, color='r', linestyle='--')
    plt.axhline(y=-0, color='g', linestyle='--')
    plt.legend(loc='upper right')
    plt.show()

    #predictions e true value
    plt.scatter(_labels, _predictions, color='blue')
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.title('Prediction and true value')
    plt.xlim([0,plt.xlim()[1]])
    plt.ylim([0,plt.ylim()[1]])
    plt.plot([-500, 500], [-500, 500])
    plt.show()

    #distribuzione degli errori
    plt.hist(discrepancies, bins=25, color='green')
    plt.title("Prediction Error")
    plt.show()

    #stampa i risultati
    print("MAE: ", mae, " (→ 0)")
    print("RMSE: ", rmse, " (→ 0)")
    print("R^2: ", r_square, " (→ 1)")

def printConfusionMatrix(_predictions, _labels):
    #valuta la classificazione
    predictions_max = np.argmax(_predictions, axis=1)
    y_test_max = np.argmax(_labels, axis=1)

    #calcola gli score
    accuracy_score_val = accuracy_score(y_test_max, predictions_max)
    precision_score_val = precision_score(y_test_max, predictions_max, average='weighted') # tp / (tp + fp)
    recall_score_val = recall_score(y_test_max, predictions_max, average='weighted') # tp / (tp + fn)
    f1_score_val = f1_score(y_test_max, predictions_max, average='weighted')

    #stampa gli score
    print("accuracy_score: %0.4f" % accuracy_score_val)
    print("precision_score: %0.4f" % precision_score_val)
    print("recall_score: %0.4f" % recall_score_val)
    print("f1_score: %0.4f" % f1_score_val)

    #ottiene e stampa la confusion matrix
    cm = confusion_matrix(y_test_max, predictions_max)
    #print(cm)
    df_cm = pd.DataFrame(cm, 
                         index = [i for i in range(cm.shape[0])],
                         columns = [i for i in range(cm.shape[1])])
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True, cmap='Blues', fmt='g')

# %%
#printDoubleInputScore()
printSingleInputScore()

#labels, predictions = getClassLabelAndPredictionsDoubleInput()
labels, predictions = getClassLabelAndPredictionsSingleInput()
printConfusionMatrix(predictions, labels)

#labels, predictions = getRegLabelAndPredictionsSingleInput()
#printR2Score(predictions, labels)
# Out:
# test score: 0.1881972005267343
# test accuracy: 0.9222270088519403
# C:\Users\Utente\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Utente\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# accuracy_score: 0.7495
# precision_score: 0.7297
# recall_score: 0.7495
# f1_score: 0.7273
