# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.externals import joblib 
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers import BatchNormalization, Concatenate,concatenate
from keras.models import load_model
from keras.optimizers import Adam
from keras.layers import Input
from keras.models import Model
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
import seaborn as sn
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Iperparametri

# %%
use_layer_regression = False
learning_rate = 0.001
logIndex = 19
dropout_rate = 0.5

hidden_layers = [100, 100]
n_output = 1

batch_size = 10
iterations = 50

# %% [markdown]
# ## Ottiene i dati

# %%
df = pd.read_csv('patterns.csv')
#print(df.head(5))

#ottiene gli input ed li divide in dummy variables
X1 = pd.get_dummies(df.iloc[:, 0]).values.astype(np.float32)
X2 = pd.get_dummies(df.iloc[:, 24]).values.astype(np.float32)
for i in range(1,24):
    X1_dummy = pd.get_dummies(df.iloc[:, i]).values.astype(np.float32)
    X2_dummy = pd.get_dummies(df.iloc[:, i+24]).values.astype(np.float32)
    X1 = np.concatenate((X1, X1_dummy), axis=1)
    X2 = np.concatenate((X2, X2_dummy), axis=1)

#ottiene gli output e li trasforma in classi    
y = df.iloc[:, -1].values.astype(np.float32)

#separa dati di train da dati di test
test_size=0.33
X1_train, X1_test, X2_train, X2_test, y_train, y_test = train_test_split(X1, X2, y, test_size=test_size, random_state=42)

X_train = np.concatenate((X1_train, X2_train), axis=1)
X_test = np.concatenate((X1_test, X2_test), axis=1)

y_train = y_train/200
y_test = y_test/200

# %% [markdown]
# ## Crea il modello ed effettua il training

# %%
n_input = X1_train.shape[1]
input1 = Input((n_input,))
input2 = Input((n_input,))
layer = concatenate([input1, input2], axis=1)
layer = Dropout(dropout_rate)(layer)
layer = Activation('relu')(layer)
    
for i in range(len(hidden_layers)):
    #aggiunge lo strato nascosto
    layer = Dense(hidden_layers[i])(layer)
    layer = Dropout(dropout_rate)(layer)
    layer = Activation('relu')(layer)
    
#aggiunge lo strato di uscita
output = Dense(n_output)(layer)

#crea il modello
model = Model([input1, input2], output)

#compila la rete neurale
optimizer = Adam(lr=learning_rate)
model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mae'])

#addestra la rete neurale
history = model.fit([X1_train, X2_train], y_train, batch_size=batch_size, epochs=iterations, validation_data=([X1_test, X2_test], y_test), verbose=1)
# Out:
# Train on 1339 samples, validate on 660 samples
# Epoch 1/50
# 1339/1339 [==============================] - 1s 406us/step - loss: 0.3564 - mean_absolute_error: 0.4586 - val_loss: 0.0603 - val_mean_absolute_error: 0.2093
# Epoch 2/50
# 1339/1339 [==============================] - 0s 167us/step - loss: 0.1051 - mean_absolute_error: 0.2543 - val_loss: 0.0715 - val_mean_absolute_error: 0.2331
# Epoch 3/50
# 1339/1339 [==============================] - 0s 159us/step - loss: 0.0640 - mean_absolute_error: 0.2023 - val_loss: 0.0603 - val_mean_absolute_error: 0.2106
# Epoch 4/50
# 1339/1339 [==============================] - 0s 158us/step - loss: 0.0454 - mean_absolute_error: 0.1687 - val_loss: 0.0537 - val_mean_absolute_error: 0.1968
# Epoch 5/50
# 1339/1339 [==============================] - 0s 162us/step - loss: 0.0394 - mean_absolute_error: 0.1608 - val_loss: 0.0448 - val_mean_absolute_error: 0.1774
# Epoch 6/50
# 1339/1339 [==============================] - 0s 161us/step - loss: 0.0322 - mean_absolute_error: 0.1457 - val_loss: 0.0326 - val_mean_absolute_error: 0.1484
# Epoch 7/50
# 1339/1339 [==============================] - 0s 168us/step - loss: 0.0291 - mean_absolute_error: 0.1394 - val_loss: 0.0289 - val_mean_absolute_error: 0.1385
# Epoch 8/50
# 1339/1339 [==============================] - 0s 168us/step - loss: 0.0255 - mean_absolute_error: 0.1309 - val_loss: 0.0271 - val_mean_absolute_error: 0.1338
# Epoch 9/50
# 1339/1339 [==============================] - 0s 151us/step - loss: 0.0225 - mean_absolute_error: 0.1225 - val_loss: 0.0236 - val_mean_absolute_error: 0.1245
# Epoch 10/50
# 1339/1339 [==============================] - 0s 155us/step - loss: 0.0223 - mean_absolute_error: 0.1230 - val_loss: 0.0199 - val_mean_absolute_error: 0.1139
# Epoch 11/50
# 1339/1339 [==============================] - 0s 156us/step - loss: 0.0213 - mean_absolute_error: 0.1193 - val_loss: 0.0189 - val_mean_absolute_error: 0.1115
# Epoch 12/50
# 1339/1339 [==============================] - 0s 157us/step - loss: 0.0201 - mean_absolute_error: 0.1164 - val_loss: 0.0178 - val_mean_absolute_error: 0.1086
# Epoch 13/50
# 1339/1339 [==============================] - 0s 162us/step - loss: 0.0192 - mean_absolute_error: 0.1141 - val_loss: 0.0177 - val_mean_absolute_error: 0.1084
# Epoch 14/50
# 1339/1339 [==============================] - 0s 152us/step - loss: 0.0188 - mean_absolute_error: 0.1133 - val_loss: 0.0167 - val_mean_absolute_error: 0.1055
# Epoch 15/50
# 1339/1339 [==============================] - 0s 155us/step - loss: 0.0190 - mean_absolute_error: 0.1141 - val_loss: 0.0183 - val_mean_absolute_error: 0.1098
# Epoch 16/50
# 1339/1339 [==============================] - 0s 152us/step - loss: 0.0187 - mean_absolute_error: 0.1123 - val_loss: 0.0167 - val_mean_absolute_error: 0.1055
# Epoch 17/50
# 1339/1339 [==============================] - 0s 153us/step - loss: 0.0171 - mean_absolute_error: 0.1072 - val_loss: 0.0157 - val_mean_absolute_error: 0.1019
# Epoch 18/50
# 1339/1339 [==============================] - 0s 151us/step - loss: 0.0176 - mean_absolute_error: 0.1097 - val_loss: 0.0148 - val_mean_absolute_error: 0.0991
# Epoch 19/50
# 1339/1339 [==============================] - 0s 153us/step - loss: 0.0176 - mean_absolute_error: 0.1089 - val_loss: 0.0149 - val_mean_absolute_error: 0.0997
# Epoch 20/50
# 1339/1339 [==============================] - 0s 153us/step - loss: 0.0170 - mean_absolute_error: 0.1061 - val_loss: 0.0142 - val_mean_absolute_error: 0.0969
# Epoch 21/50
# 1339/1339 [==============================] - 0s 158us/step - loss: 0.0164 - mean_absolute_error: 0.1048 - val_loss: 0.0142 - val_mean_absolute_error: 0.0964
# Epoch 22/50
# 1339/1339 [==============================] - 0s 188us/step - loss: 0.0162 - mean_absolute_error: 0.1038 - val_loss: 0.0148 - val_mean_absolute_error: 0.0984
# Epoch 23/50
# 1339/1339 [==============================] - 0s 161us/step - loss: 0.0163 - mean_absolute_error: 0.1046 - val_loss: 0.0141 - val_mean_absolute_error: 0.0958
# Epoch 24/50
# 1339/1339 [==============================] - 0s 188us/step - loss: 0.0156 - mean_absolute_error: 0.1028 - val_loss: 0.0142 - val_mean_absolute_error: 0.0957
# Epoch 25/50
# 1339/1339 [==============================] - 0s 156us/step - loss: 0.0146 - mean_absolute_error: 0.0985 - val_loss: 0.0145 - val_mean_absolute_error: 0.0966
# Epoch 26/50
# 1339/1339 [==============================] - 0s 154us/step - loss: 0.0151 - mean_absolute_error: 0.0994 - val_loss: 0.0129 - val_mean_absolute_error: 0.0911
# Epoch 27/50
# 1339/1339 [==============================] - 0s 174us/step - loss: 0.0146 - mean_absolute_error: 0.0979 - val_loss: 0.0127 - val_mean_absolute_error: 0.0905
# Epoch 28/50
# 1339/1339 [==============================] - 0s 190us/step - loss: 0.0158 - mean_absolute_error: 0.1013 - val_loss: 0.0139 - val_mean_absolute_error: 0.0946
# Epoch 29/50
# 1339/1339 [==============================] - 0s 165us/step - loss: 0.0151 - mean_absolute_error: 0.0998 - val_loss: 0.0125 - val_mean_absolute_error: 0.0902
# Epoch 30/50
# 1339/1339 [==============================] - 0s 176us/step - loss: 0.0138 - mean_absolute_error: 0.0962 - val_loss: 0.0132 - val_mean_absolute_error: 0.0920
# Epoch 31/50
# 1339/1339 [==============================] - 0s 165us/step - loss: 0.0142 - mean_absolute_error: 0.0971 - val_loss: 0.0132 - val_mean_absolute_error: 0.0922
# Epoch 32/50
# 1339/1339 [==============================] - 0s 211us/step - loss: 0.0140 - mean_absolute_error: 0.0962 - val_loss: 0.0126 - val_mean_absolute_error: 0.0899
# Epoch 33/50
# 1339/1339 [==============================] - 0s 187us/step - loss: 0.0141 - mean_absolute_error: 0.0969 - val_loss: 0.0128 - val_mean_absolute_error: 0.0913
# Epoch 34/50
# 1339/1339 [==============================] - 0s 168us/step - loss: 0.0138 - mean_absolute_error: 0.0962 - val_loss: 0.0121 - val_mean_absolute_error: 0.0886
# Epoch 35/50
# 1339/1339 [==============================] - 0s 186us/step - loss: 0.0137 - mean_absolute_error: 0.0955 - val_loss: 0.0114 - val_mean_absolute_error: 0.0859
# Epoch 36/50
# 1339/1339 [==============================] - 0s 159us/step - loss: 0.0132 - mean_absolute_error: 0.0933 - val_loss: 0.0131 - val_mean_absolute_error: 0.0919
# Epoch 37/50
# 1339/1339 [==============================] - 0s 158us/step - loss: 0.0131 - mean_absolute_error: 0.0928 - val_loss: 0.0115 - val_mean_absolute_error: 0.0859
# Epoch 38/50
# 1339/1339 [==============================] - 0s 174us/step - loss: 0.0129 - mean_absolute_error: 0.0907 - val_loss: 0.0126 - val_mean_absolute_error: 0.0900
# Epoch 39/50
# 1339/1339 [==============================] - 0s 162us/step - loss: 0.0135 - mean_absolute_error: 0.0944 - val_loss: 0.0123 - val_mean_absolute_error: 0.0892
# Epoch 40/50
# 1339/1339 [==============================] - 0s 165us/step - loss: 0.0124 - mean_absolute_error: 0.0904 - val_loss: 0.0118 - val_mean_absolute_error: 0.0871
# Epoch 41/50
# 1339/1339 [==============================] - 0s 232us/step - loss: 0.0128 - mean_absolute_error: 0.0929 - val_loss: 0.0134 - val_mean_absolute_error: 0.0937
# Epoch 42/50
# 1339/1339 [==============================] - 0s 168us/step - loss: 0.0132 - mean_absolute_error: 0.0929 - val_loss: 0.0122 - val_mean_absolute_error: 0.0892
# Epoch 43/50
# 1339/1339 [==============================] - 0s 162us/step - loss: 0.0126 - mean_absolute_error: 0.0906 - val_loss: 0.0121 - val_mean_absolute_error: 0.0886
# Epoch 44/50
# 1339/1339 [==============================] - 0s 161us/step - loss: 0.0125 - mean_absolute_error: 0.0900 - val_loss: 0.0116 - val_mean_absolute_error: 0.0863
# Epoch 45/50
# 1339/1339 [==============================] - 0s 162us/step - loss: 0.0128 - mean_absolute_error: 0.0913 - val_loss: 0.0116 - val_mean_absolute_error: 0.0867
# Epoch 46/50
# 1339/1339 [==============================] - 0s 163us/step - loss: 0.0124 - mean_absolute_error: 0.0895 - val_loss: 0.0125 - val_mean_absolute_error: 0.0904
# Epoch 47/50
# 1339/1339 [==============================] - 0s 164us/step - loss: 0.0125 - mean_absolute_error: 0.0904 - val_loss: 0.0121 - val_mean_absolute_error: 0.0886
# Epoch 48/50
# 1339/1339 [==============================] - 0s 163us/step - loss: 0.0124 - mean_absolute_error: 0.0904 - val_loss: 0.0126 - val_mean_absolute_error: 0.0907
# Epoch 49/50
# 1339/1339 [==============================] - 0s 165us/step - loss: 0.0124 - mean_absolute_error: 0.0900 - val_loss: 0.0125 - val_mean_absolute_error: 0.0902
# Epoch 50/50
# 1339/1339 [==============================] - 0s 159us/step - loss: 0.0124 - mean_absolute_error: 0.0902 - val_loss: 0.0119 - val_mean_absolute_error: 0.0879

# %% [markdown]
# ## Stampa le perdite

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model MAE')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Valuta il modello in base alla regressione

# %%
#ottiene le predictions dal modello
predictions = model.predict([X1_test, X2_test]).flatten()*200
labels = y_test*200

# %%
#ottiene l' R^2 score (ottimo valore se tendente a 1)
r_square = r2_score(labels, predictions) 

#ottiene il Mean Absolute Error (MAE) (ottimo valore se tendente a 0)
mae = mean_absolute_error(labels, predictions)

#ottiene il Root Mean Squared Error (RMSE) (ottimo valore se tendente a 0)
rmse = mean_squared_error(labels, predictions)**0.5

#stampa le varie discrepanze (differenza tra il valore atteso ed il valore predetto)
discrepancies = []
for i in range(len(labels)):
    discrepancies.append(labels[i]-predictions[i])
plt.title('Evaluating regression model')
plt.plot(discrepancies, label='Discrepancies', color='orange')
plt.axhline(y=mae, color='b', linestyle='--', label='MAE')
plt.axhline(y=-mae, color='b', linestyle='--')
plt.axhline(y=rmse, color='r', linestyle='--', label='RMSE')
plt.axhline(y=-rmse, color='r', linestyle='--')
plt.axhline(y=-0, color='g', linestyle='--')
plt.legend(loc='upper right')
plt.show()

#predictions e true value
plt.scatter(labels, predictions, color='blue')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('Prediction and true value')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
plt.plot([-500, 500], [-500, 500])
plt.show()

#distribuzione degli errori
plt.hist(discrepancies, bins=25, color='green')
plt.title("Prediction Error")
plt.show()

#stampa i risultati
print("MAE: ", mae, " (→ 0)")
print("RMSE: ", rmse, " (→ 0)")
print("R^2: ", r_square, " (→ 1)")
# Out:
# MAE:  17.576141  (→ 0)
# RMSE:  21.79188100832187  (→ 0)
# R^2:  0.31563749539146047  (→ 1)

# %% [markdown]
# ## Valuta il modello in base alla classificazione

# %%
#trasforma le predizioni in classi
def transformToClass(yr):
    yc = []
    for i in range(len(yr)):
        yi = np.zeros(7)
        if (yr[i]<70):                  yi[0] = 1 #A
        if (yr[i]>=70  and yr[i]<=83) : yi[1] = 1 #B
        if (yr[i]>=84  and yr[i]<=98) : yi[2] = 1 #C
        if (yr[i]>=99  and yr[i]<=113): yi[3] = 1 #D
        if (yr[i]>=114 and yr[i]<=128): yi[4] = 1 #E
        if (yr[i]>=129 and yr[i]<=143): yi[5] = 1 #F
        if (yr[i]>143):                 yi[6] = 1 #G
        yc.append(yi)
    yr = np.array(yc)
    return yr


c_labels = transformToClass(labels)
c_predictions = transformToClass(predictions)

# %%
#valuta la classificazione
predictions_max = np.argmax(c_predictions, axis=1)
y_test_max = np.argmax(c_labels, axis=1)

#calcola gli score
accuracy_score_val = accuracy_score(y_test_max, predictions_max)
precision_score_val = precision_score(y_test_max, predictions_max, average='weighted') # tp / (tp + fp)
recall_score_val = recall_score(y_test_max, predictions_max, average='weighted') # tp / (tp + fn)
f1_score_val = f1_score(y_test_max, predictions_max, average='weighted')

#stampa gli score
print("accuracy_score: %0.4f" % accuracy_score_val)
print("precision_score: %0.4f" % precision_score_val)
print("recall_score: %0.4f" % recall_score_val)
print("f1_score: %0.4f" % f1_score_val)

#ottiene e stampa la confusion matrix
cm = confusion_matrix(y_test_max, predictions_max)
df_cm = pd.DataFrame(cm, 
                     index = [i for i in range(cm.shape[0])],
                     columns = [i for i in range(cm.shape[1])])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap='Blues', fmt='g')
# Out:
# accuracy_score: 0.4015
# precision_score: 0.3433
# recall_score: 0.4015
# f1_score: 0.3612
# C:\Users\Utente\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Utente\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
